# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from pandas.plotting import scatter_matrix
from itertools import combinations
# %matplotlib inline

# %%
df = pd.read_csv('loan.csv') 
df.head()
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000
# 21          21.98         665           36         6666.67        22000

# %%
df['approved']=df['Interest.Rate']<=12

df= df.dropna()
""" df.info() would tell you if bad"""

df.head()
# Out:
#     Interest.Rate  FICO.Score  Loan.Length  Monthly.Income  Loan.Amount  \
# 6           15.31         670           36         4891.67         6000
# 11          19.72         670           36         3575.00         2000
# 12          14.27         665           36         4250.00        10625
# 13          21.67         670           60        14166.67        28000
# 21          21.98         665           36         6666.67        22000
#
#     approved
# 6      False
# 11     False
# 12     False
# 13     False
# 21     False

# %%
scatter_matrix(df, figsize=(12,12))
None

# %%
y = df.approved
X = df[['FICO.Score']]

# %%
X.head()
# Out:
#     FICO.Score
# 6          670
# 11         670
# 12         665
# 13         670
# 21         665

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
model = LogisticRegression().fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.78016726403823178

# %%
y = df.approved
rows = []
for i in range(1,5):
    combos = list(combinations(['FICO.Score', 'Loan.Length', 'Monthly.Income', 'Loan.Amount'],i))
    for combo in combos:
        model = LogisticRegression(fit_intercept=True)
        accuracy = cross_val_score(model, df[list(combo)], df.approved, cv=10, scoring='accuracy').mean()
        rows.append({'Accuracy': accuracy, 'Columns': combo})
df1 = pd.DataFrame(rows)
df1.head()
# Out:
#    Accuracy                    Columns
# 0  0.765154              (FICO.Score,)
# 1  0.603441             (Loan.Length,)
# 2  0.603040          (Monthly.Income,)
# 3  0.603441             (Loan.Amount,)
# 4  0.837152  (FICO.Score, Loan.Length)

# %%
df1.max(0,5)
# Out:
# Accuracy                         0.856703
# Columns     (Monthly.Income, Loan.Amount)
# dtype: object

# %%
"""refit it"""
# Out:
# 'refit it'

# %%
m1 = LogisticRegression().fit(df[['FICO.Score']], df.approved)

# %%
m1.coef_
# Out:
# array([[ 0.02417872]])

# %%
m1.intercept_
# Out:
# array([-17.48849485])

# %%
m1.predict([[725]])
# Out:
# array([ True], dtype=bool)

# %%
y_actual = df.approved

# %%
y = df.approved
X = df[['FICO.Score']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
y_hat = m1.predict(X_test)

# %%
confusion_matrix(y_test, y_hat).ravel()
# Out:
# array([473,  37, 121, 194], dtype=int64)

# %%
"""Tn FP FN TP"""
# Out:
# 'Tn FP FN TP'

# %%
Recall = round(194/(121+194),4)
Percision = round(194/(194+37),4)
Accuracy = round(m1.score(X_test, y_test),4)

# %%
print ("Recall: ", Recall)
print ("Percision :", Percision)
print ("Accuracy :",Accuracy)
# Out:
# Recall:  0.6159
# Percision : 0.8398
# Accuracy : 0.8085
